# %%
# Author: Shaik Faizan Roshan Ali   
# Date: 18th August 2021
# Email: alsahercoder@gmail.com
# About: Classification using Linear Support Vector Classifier on Social Network Ads dataset
# Dataset: https://www.kaggle.com/d4rklucif3r/social-network-ads

# %%
# import libraries
import pandas as pd
import numpy as np
import missingno as msno
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC

# %%
# reading dataset
df = pd.read_csv("Social_Network_Ads.csv")
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
# visualising null values
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
# droping user id
df = df.drop(["User ID"], axis=1)

# %%
df.head() # verifying dataset
# Out:
#    Gender  Age  EstimatedSalary  Purchased
# 0    Male   19            19000          0
# 1    Male   35            20000          0
# 2  Female   26            43000          0
# 3  Female   27            57000          0
# 4    Male   19            76000          0

# %%
# Label Encoding Gender Values
label_encoder = LabelEncoder()
df["Gender"] = label_encoder.fit_transform(df["Gender"])
df
# Out:
#      Gender  Age  EstimatedSalary  Purchased
# 0         1   19            19000          0
# 1         1   35            20000          0
# 2         0   26            43000          0
# 3         0   27            57000          0
# 4         1   19            76000          0
# ..      ...  ...              ...        ...
# 395       0   46            41000          1
# 396       1   51            23000          1
# 397       0   50            20000          1
# 398       1   36            33000          0
# 399       0   49            36000          1
#
# [400 rows x 4 columns]

# %%
# Dividing independent and dependent values of dataset
scaler = StandardScaler()

X = df.drop(["Purchased"], axis=1)
Y = df["Purchased"]

X = scaler.fit_transform(X)

# %%
# splitting the training and testing data
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state = 42)

linear_svc = LinearSVC(max_iter = 2000, random_state = 42)
svm_model = linear_svc.fit(x_train, y_train)

train_score = svm_model.score(x_test, y_test)
test_score = svm_model.score(x_train, y_train)

print("Train score: ", train_score)
print("Test score: ", test_score)
# Out:
# Train score:  0.8875
# Test score:  0.81875
